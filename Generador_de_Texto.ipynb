# %% [markdown]
# <a href="https://colab.research.google.com/github/marisolriveraslrzn/CodingIA/blob/main/Generador_de_Texto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Generador de Texto con GPT-2
#
# 1. Configuracion del entorno y modelo
# 2. Text generation

# %%
#1. Instalacion de librerias

# !pip install transformers
# !pip install torch

# %%
#Configuracion del entorno

from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

tokenizer = AutoTokenizer.from_pretrained("flax-community/papuGaPT2")
model = AutoModelForCausalLM.from_pretrained("flax-community/papuGaPT2")

generator = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# Loading weights:   0%|          | 0/149 [00:00<?, ?it/s]
# [transformers] GPT2LMHeadModel LOAD REPORT from: flax-community/papuGaPT2
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...11}.attn.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#2. Generador de texto

text = generator("Artificial Inteligence is", max_length=20, temperature=0.2)
print(text[0]['generated_text'])
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
text = generator("Respoder en español: La inteligencia artificial es", max_length=15, temperature=0.5)

print(text[0]['generated_text'])
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=15) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Respoder en español: La inteligencia artificial escial de la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la actividad en el año, en la a

# %%
#Parametros
#top_p = % probabilida
#repetition_penality = penalizar repeticiones
#top_k = familia de palabras
#do_sample = improviso o no improviso

text = generator("Artificial Inteligence is",
                 max_new_tokens=60,
                 temperature=1.1,
                 top_p=0.92,
                 repetition_penalty=1,
                 top_k=60,
                 do_sample=True,
                 )
print(text[0]['generated_text'])
# Out:
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Inteligence is software does not find the name and the required destination. Write Us can contain the information and cost from the same users of an exclusive information. You do not just can cause your extension,

# %%
text = generator("I am detective Sherlock Holmes, I am conducting an investigation. I have just noticed that on the desk",
                 max_new_tokens=60,
                 temperature=1.1,
                 top_p=0.92,
                 repetition_penalty=1,
                 top_k=60,
                 do_sample=False,
                 )
print(text[0]['generated_text'])
# Out:
# [transformers] The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# I am detective Sherlock Holmes, I am conducting an investigation. I have just noticed that on the desk to their own action. I am able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able to be able

# %% [markdown]
# #ACTIVIDAD

# %%
#1. Instalacion de librerias
#Configuracion del entorno  --> "datificate/gpt2-small-spanish"
#2. Generador de texto
