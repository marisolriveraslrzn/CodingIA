# %% [markdown]
# <a href="https://colab.research.google.com/github/marisolriveraslrzn/CodingIA/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer

#Descarga de recursos
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('punkt_tab')

#Texto a tokenizar
text = "Michael Jackson is singing a new song."

print("Tokenizacion: ")
print(sent_tokenize(text))

print("\nWords: ")
print(word_tokenize(text))

#NLP
lemmatizer = WordNetLemmatizer()
stemmer = SnowballStemmer("english")

# Palabras a analizar
words = ["singing","sang","sings"]

#Resultados

print("\n{:<12} {:<12} {:<12}".format("Word", "Lemma", "Stem"))

for word in words:
    lemma = lemmatizer.lemmatize(word, pos='v')
    stem = stemmer.stem(word)

    print("{:<12} {:<12} {:<12}".format(word, lemma, stem))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokenizacion:
# ['Michael Jackson is singing a new song.']
#
# Words:
# ['Michael', 'Jackson', 'is', 'singing', 'a', 'new', 'song', '.']
#
# Word         Lemma        Stem
# singing      sing         sing
# sang         sing         sang
# sings        sing         sing
